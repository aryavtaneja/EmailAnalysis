# %%
from dotenv import load_dotenv

import os

import openai
from openai.embeddings_utils import get_embedding
import pandas as pd
import tiktoken

load_dotenv()

openai.api_key = os.getenv("OPENAI_API_KEY")

embedding_model = "text-embedding-ada-002"
max_tokens = 8000

# %%
df = pd.read_parquet('olddata.parquet')
df = df.dropna(subset=['Replied To'])
df = df.drop(columns=['Labels'])
df.head()
# Out:
#                                              Subject
# 0  VINEET, Remember To Purchase Your Getaway Star...  \
# 1      Spring Recital next Saturday May 20th at 5:00
# 2  [Class of 2028] Save the date - 7th Grade End ...
# 3  [Mantri Celestia] Special Notice: Power Shutdo...
# 4         We're Giving You Up to 40% Off Sale Styles
#
#                                               Sender          Date
# 0  Hilton Grand Vacations <hgv@travel2.hiltongran...  1.683869e+09  \
# 1         Andrew Bushnell <fiddlersroof@outlook.com>  1.683868e+09
# 2               Tushar Gupta <m@mail1.veracross.com>  1.683867e+09
# 3  Mantri Celestia helpdesk <donotreply@apnacompl...  1.683866e+09
# 4  Banana Republic <bananarepublic@email.bananare...  1.683864e+09
#
#                                                 Body  Replied To
# 0  Your 3-Night Vacation Can Get You $100 Towards...           0
# 1                                                              0
# 2  Hello class of 2028 families, \r\nWe are plann...           0
# 3                                                              0
# 4  \r\n\r\nWe're Giving You Up to 40% Off Sale St...           0

# %%
df = df.groupby('Replied To').head(870)
df.head()
# Out:
#                                              Subject
# 0  VINEET, Remember To Purchase Your Getaway Star...  \
# 1      Spring Recital next Saturday May 20th at 5:00
# 2  [Class of 2028] Save the date - 7th Grade End ...
# 3  [Mantri Celestia] Special Notice: Power Shutdo...
# 4         We're Giving You Up to 40% Off Sale Styles
#
#                                               Sender          Date
# 0  Hilton Grand Vacations <hgv@travel2.hiltongran...  1.683869e+09  \
# 1         Andrew Bushnell <fiddlersroof@outlook.com>  1.683868e+09
# 2               Tushar Gupta <m@mail1.veracross.com>  1.683867e+09
# 3  Mantri Celestia helpdesk <donotreply@apnacompl...  1.683866e+09
# 4  Banana Republic <bananarepublic@email.bananare...  1.683864e+09
#
#                                                 Body  Replied To
# 0  Your 3-Night Vacation Can Get You $100 Towards...           0
# 1                                                              0
# 2  Hello class of 2028 families, \r\nWe are plann...           0
# 3                                                              0
# 4  \r\n\r\nWe're Giving You Up to 40% Off Sale St...           0

# %%
#convert the unix timestamp in each date to a human-readable text
df['Date'] = pd.to_datetime(df['Date'], unit='s')

df.head()
# Out:
#                                              Subject
# 0  VINEET, Remember To Purchase Your Getaway Star...  \
# 1      Spring Recital next Saturday May 20th at 5:00
# 2  [Class of 2028] Save the date - 7th Grade End ...
# 3  [Mantri Celestia] Special Notice: Power Shutdo...
# 4         We're Giving You Up to 40% Off Sale Styles
#
#                                               Sender                Date
# 0  Hilton Grand Vacations <hgv@travel2.hiltongran... 2023-05-12 05:19:17  \
# 1         Andrew Bushnell <fiddlersroof@outlook.com> 2023-05-12 04:58:48
# 2               Tushar Gupta <m@mail1.veracross.com> 2023-05-12 04:47:09
# 3  Mantri Celestia helpdesk <donotreply@apnacompl... 2023-05-12 04:36:01
# 4  Banana Republic <bananarepublic@email.bananare... 2023-05-12 04:01:26
#
#                                                 Body  Replied To
# 0  Your 3-Night Vacation Can Get You $100 Towards...           0
# 1                                                              0
# 2  Hello class of 2028 families, \r\nWe are plann...           0
# 3                                                              0
# 4  \r\n\r\nWe're Giving You Up to 40% Off Sale St...           0

# %%
#create a new column with the combined text
df = df[['Subject', 'Sender', 'Date', 'Body', 'Replied To']]

#make a combined column with the subject, sender and body for each row
for index, row in df.iterrows():
    df.at[index, 'combined'] = f'Subject: {row["Subject"].strip()}; Sender: {row["Sender"].strip()}; Body: {row["Body"].strip()}'

df.head()
# Out:
#                                              Subject
# 0  VINEET, Remember To Purchase Your Getaway Star...  \
# 1      Spring Recital next Saturday May 20th at 5:00
# 2  [Class of 2028] Save the date - 7th Grade End ...
# 3  [Mantri Celestia] Special Notice: Power Shutdo...
# 4         We're Giving You Up to 40% Off Sale Styles
#
#                                               Sender                Date
# 0  Hilton Grand Vacations <hgv@travel2.hiltongran... 2023-05-12 05:19:17  \
# 1         Andrew Bushnell <fiddlersroof@outlook.com> 2023-05-12 04:58:48
# 2               Tushar Gupta <m@mail1.veracross.com> 2023-05-12 04:47:09
# 3  Mantri Celestia helpdesk <donotreply@apnacompl... 2023-05-12 04:36:01
# 4  Banana Republic <bananarepublic@email.bananare... 2023-05-12 04:01:26
#
#                                                 Body  Replied To
# 0  Your 3-Night Vacation Can Get You $100 Towards...           0  \
# 1                                                              0
# 2  Hello class of 2028 families, \r\nWe are plann...           0
# 3                                                              0
# 4  \r\n\r\nWe're Giving You Up to 40% Off Sale St...           0
#
#                                             combined
# 0  Subject: VINEET, Remember To Purchase Your Get...
# 1  Subject: Spring Recital next Saturday May 20th...
# 2  Subject: [Class of 2028] Save the date - 7th G...
# 3  Subject: [Mantri Celestia] Special Notice: Pow...
# 4  Subject: We're Giving You Up to 40% Off Sale S...

# %%
encoding = tiktoken.encoding_for_model(embedding_model)

df["n_tokens"] = df["combined"].apply(lambda x: len(encoding.encode(x)))
df = df[df["n_tokens"] <= max_tokens]
len(df)
# Out:
# 1457

# %%
df["embedding"] = df["combined"].apply(lambda x: get_embedding(x, engine=embedding_model))

# %%
df.head()
# Out:
#                                              Subject
# 0  VINEET, Remember To Purchase Your Getaway Star...  \
# 1      Spring Recital next Saturday May 20th at 5:00
# 2  [Class of 2028] Save the date - 7th Grade End ...
# 3  [Mantri Celestia] Special Notice: Power Shutdo...
# 4         We're Giving You Up to 40% Off Sale Styles
#
#                                               Sender          Date
# 0  Hilton Grand Vacations <hgv@travel2.hiltongran...  1.683869e+09  \
# 1         Andrew Bushnell <fiddlersroof@outlook.com>  1.683868e+09
# 2               Tushar Gupta <m@mail1.veracross.com>  1.683867e+09
# 3  Mantri Celestia helpdesk <donotreply@apnacompl...  1.683866e+09
# 4  Banana Republic <bananarepublic@email.bananare...  1.683864e+09
#
#                                                 Body  Replied To
# 0  Your 3-Night Vacation Can Get You $100 Towards...           0  \
# 1                                                              0
# 2  Hello class of 2028 families, \r\nWe are plann...           0
# 3                                                              0
# 4  \r\n\r\nWe're Giving You Up to 40% Off Sale St...           0
#
#                                             combined  n_tokens
# 0  Subject: VINEET, Remember To Purchase Your Get...      3705  \
# 1  Subject: Spring Recital next Saturday May 20th...        35
# 2  Subject: [Class of 2028] Save the date - 7th G...       155
# 3  Subject: [Mantri Celestia] Special Notice: Pow...        48
# 4  Subject: We're Giving You Up to 40% Off Sale S...      5416
#
#                                            embedding
# 0  [-0.008335459977388382, -0.007523390464484692,...
# 1  [-0.03298372030258179, 0.0026079996023327112, ...
# 2  [-0.008779299445450306, -0.004117605742067099,...
# 3  [-0.00916092749685049, -0.021061832085251808, ...
# 4  [-0.046990904957056046, -0.01633710041642189, ...

# %%
#delete combined and n_tokens columns
df = df.drop(columns=['combined', 'n_tokens'])

# %%
df.head()
# Out:
#                                              Subject
# 0  VINEET, Remember To Purchase Your Getaway Star...  \
# 1      Spring Recital next Saturday May 20th at 5:00
# 2  [Class of 2028] Save the date - 7th Grade End ...
# 3  [Mantri Celestia] Special Notice: Power Shutdo...
# 4         We're Giving You Up to 40% Off Sale Styles
#
#                                               Sender          Date
# 0  Hilton Grand Vacations <hgv@travel2.hiltongran...  1.683869e+09  \
# 1         Andrew Bushnell <fiddlersroof@outlook.com>  1.683868e+09
# 2               Tushar Gupta <m@mail1.veracross.com>  1.683867e+09
# 3  Mantri Celestia helpdesk <donotreply@apnacompl...  1.683866e+09
# 4  Banana Republic <bananarepublic@email.bananare...  1.683864e+09
#
#                                                 Body  Replied To
# 0  Your 3-Night Vacation Can Get You $100 Towards...           0  \
# 1                                                              0
# 2  Hello class of 2028 families, \r\nWe are plann...           0
# 3                                                              0
# 4  \r\n\r\nWe're Giving You Up to 40% Off Sale St...           0
#
#                                            embedding
# 0  [-0.008335459977388382, -0.007523390464484692,...
# 1  [-0.03298372030258179, 0.0026079996023327112, ...
# 2  [-0.008779299445450306, -0.004117605742067099,...
# 3  [-0.00916092749685049, -0.021061832085251808, ...
# 4  [-0.046990904957056046, -0.01633710041642189, ...

# %%
#rename 'Replied To' to 'RepliedTo'
df = df.rename(columns={'Replied To': 'RepliedTo'})
df.head()
# Out:
#                                              Subject
# 0  VINEET, Remember To Purchase Your Getaway Star...  \
# 1      Spring Recital next Saturday May 20th at 5:00
# 2  [Class of 2028] Save the date - 7th Grade End ...
# 3  [Mantri Celestia] Special Notice: Power Shutdo...
# 4         We're Giving You Up to 40% Off Sale Styles
#
#                                               Sender          Date
# 0  Hilton Grand Vacations <hgv@travel2.hiltongran...  1.683869e+09  \
# 1         Andrew Bushnell <fiddlersroof@outlook.com>  1.683868e+09
# 2               Tushar Gupta <m@mail1.veracross.com>  1.683867e+09
# 3  Mantri Celestia helpdesk <donotreply@apnacompl...  1.683866e+09
# 4  Banana Republic <bananarepublic@email.bananare...  1.683864e+09
#
#                                                 Body  RepliedTo
# 0  Your 3-Night Vacation Can Get You $100 Towards...          0  \
# 1                                                             0
# 2  Hello class of 2028 families, \r\nWe are plann...          0
# 3                                                             0
# 4  \r\n\r\nWe're Giving You Up to 40% Off Sale St...          0
#
#                                            embedding
# 0  [-0.008335459977388382, -0.007523390464484692,...
# 1  [-0.03298372030258179, 0.0026079996023327112, ...
# 2  [-0.008779299445450306, -0.004117605742067099,...
# 3  [-0.00916092749685049, -0.021061832085251808, ...
# 4  [-0.046990904957056046, -0.01633710041642189, ...

# %%
#save as data.parquet
df.to_parquet('data.parquet')
